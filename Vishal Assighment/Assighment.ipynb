# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd 
 
# Define the file path using forward slashes 
file_path = r'C:\Users\HP ZBOOK\OneDrive\Desktop\Vishal Assighment\datasate.csv'

data = pd.read_csv(file_path) 
# Display the first few rows of the DataFrame 
print(data.head())

# %%
# Describe data
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
plt.title('World Population')
sns.distplot(data['Initial Year'])
plt.show()
# Out:
# C:\Users\HP ZBOOK\AppData\Local\Temp\ipykernel_11496\3082458394.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Salary'])

# %%
# Relationship between InitialYear and LastYear
plt.scatter(data['World Population'], data['InitialYear'], color = 'blue')
plt.title('InitialYear vs LastYear')
plt.xlabel('Years of LastYear')
plt.ylabel('InitialYear')
plt.box(False)
plt.show()

# %%
# Splitting variables
X = data.iloc[:, :1]  # independent
y = data.iloc[:, 1:]  # dependent

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Define the file path using forward slashes
file_path = r'C:\Users\HP ZBOOK\OneDrive\Desktop\Perdeep\InitialYear_Data.csv'

# Read the CSV file into a DataFrame
data = pd.read_csv(file_path)

# Assuming the dataset has columns 'YearsLastYear' and 'InitialYear'
X = data[['YearsLastYear']]
y = data['InitialYear']

# Splitting dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Create a scatter plot
plt.scatter(data['YearsLastYear'], data['InitialYear'], color='darkblue')
plt.title('InitialYear vs LastYear')
plt.xlabel('Years of LastYear')
plt.ylabel('InitialYear')
plt.box(False)
plt.show()

print("Training set size:", X_train.shape[0])
print("Test set size:", X_test.shape[0])

# %%
# Splitting variables
X =data.iloc[:, :1]  # independent
y =data.iloc[:, 1:]  # dependent

# %%
# Splitting dataset into test/train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Define the file path using a raw string
file_path = r'C:\Users\HP ZBOOK\OneDrive\Desktop\Perdeep\InitialYear_Data.csv'

# Read the CSV file into a DataFrame
data = pd.read_csv(file_path)

# Assuming the dataset has columns 'YearsLastYear' and 'InitialYear'
X = data[['YearsLastYear']]
y = data['InitialYear']

# Splitting dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Train the linear regression model
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predict the test set results
y_pred = regressor.predict(X_test)

# Plot the training data
plt.scatter(X_train, y_train, color='blue', label='Training data')
# Plot the regression line based on training data
plt.plot(X_train, regressor.predict(X_train), color='red', label='Regression line')
plt.title('InitialYear vs LastYear (Training set)')
plt.xlabel('Years of LastYear')
plt.ylabel('InitialYear')
plt.legend()
plt.show()

# Plot the test data
plt.scatter(X_test, y_test, color='green', label='Test data')
# Plot the regression line based on training data
plt.plot(X_train, regressor.predict(X_train), color='red', label='Regression line')
plt.title('InitialYear vs LastYear (Test set)')
plt.xlabel('Years of LastYear')
plt.ylabel('InitialYear')
plt.legend()
plt.show()

print("Model coefficients:", regressor.coef_)
print("Model intercept:", regressor.intercept_)
print("Predicted salaries:", y_pred)
print("Actual salaries:", y_test.values)

# %%
# Regressor coefficients and intercept
print(f'Coefficient: {regressor.coef_}')
print(f'Intercept: {regressor.intercept_}')
# Out:
# Coefficient: [9312.57512673]
# Intercept: 26780.09915062818

# %%
# Get dataset
# Using raw string literal
data = pd.read_csv(r'C:\Users\HP ZBOOK\OneDrive\Desktop\Vishal Assighment\datasate.csv')

data.head()
# Out:
#               World Population    Unnamed: 1 Unnamed: 2
# 0                       C.Name  Initial Year  Last Year
# 1                        Aruba           15%        63%
# 2  Africa Eastern and Southern          115%       163%
# 3                  Afghanistan          215%       263%
# 4   Africa Western and Central          315%       363%

# %%
# Describe data
data.describe()
# Out:
#        World Population    Unnamed: 1 Unnamed: 2
# count                29            29         29
# unique               29            29         29
# top              C.Name  Initial Year  Last Year
# freq                  1             1          1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load your data into a DataFrame
data = pd.read_csv(r'C:\Users\HP ZBOOK\OneDrive\Desktop\Vishal Assighment\datasate.csv')

# Assuming 'Initial-Year' is the column of interest

plt.title('World Population')

plt.show()
